# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from collections import namedtuple
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from utils import *
from ES import ES
from benchmarks import *

# %%
benchData = namedtuple('benchData', 'func, domain, min, argmin')

benchList = {
    'Sphere':benchData(rast, (-5.12, 5.12), 0, "0,0,.."),
    'Griewank':benchData(griewank, (-500, 500), 0, "0,0,.."),
    'Rastrigin':benchData(rast, (-5.12, 5.12), 0, "0,0,.."),
    'Schwefel':benchData(rast, (-500, 500), 0, "1,1,.."),
    'Dixon & Price':benchData(rast, (-10, 10), 0, "0,0,.."),
}

evkwargs = {
        'mi':500,
        'Lambda':4000,
        'd':50,
        'number_of_iterations':400,
        'K':0.75,
}

pltkwargs = {
    'tries':2,
    'barplot':True,
    'file':False,
    'verbose' : True
}
for name in benchList:
    for plus in [True, False]:
        evkwargs = {
            **evkwargs,
            'population_evaluation': benchList[name].func,
            'domain': benchList[name].domain,
            'plus': plus
        }
        pltkwargs['title'] = f'Name: {name} {"plus " if plus else ""} (min: {benchList[name].min})'
        pltkwargs['filename'] = f'z1_{name}{"_plus " if plus else ""}'
        
        plot_scores(ES, **pltkwargs, **evkwargs)
# Out:
# Name: Sphere plus  (min: 0): próba 0; wynik: 172.1272443323976; czas: 43.2378511428833
# Name: Sphere plus  (min: 0): próba 1; wynik: 224.85978813210096; czas: 36.90970993041992
# Wynik Name: Sphere plus  (min: 0): 172.1272443323976; czas: 80.97010850906372,
# Name: Sphere  (min: 0): próba 0; wynik: 197.99722341720968; czas: 26.625389575958252
# Name: Sphere  (min: 0): próba 1; wynik: 188.0467487717496; czas: 26.361700773239136
# Wynik Name: Sphere  (min: 0): 188.0467487717496; czas: 53.696754455566406,
# Name: Griewank plus  (min: 0): próba 0; wynik: 1.3371980622031547; czas: 28.689409971237183
# Name: Griewank plus  (min: 0): próba 1; wynik: 0.413024536144887; czas: 27.892598390579224
# Wynik Name: Griewank plus  (min: 0): 0.413024536144887; czas: 57.3367657661438,
# Name: Griewank  (min: 0): próba 0; wynik: 1.5200644956227432; czas: 25.352782726287842
# Name: Griewank  (min: 0): próba 1; wynik: 15.08446197623078; czas: 25.733396768569946
# Wynik Name: Griewank  (min: 0): 1.5200644956227432; czas: 51.831111431121826,
# Name: Rastrigin plus  (min: 0): próba 0; wynik: 180.08719020626882; czas: 28.97091317176819
# Name: Rastrigin plus  (min: 0): próba 1; wynik: 244.76055172613766; czas: 27.24721336364746
# Wynik Name: Rastrigin plus  (min: 0): 180.08719020626882; czas: 57.07374620437622,
# Name: Rastrigin  (min: 0): próba 0; wynik: 249.73321207224546; czas: 24.129992961883545
# Name: Rastrigin  (min: 0): próba 1; wynik: 266.64746385501314; czas: 20.234113693237305
# Wynik Name: Rastrigin  (min: 0): 249.73321207224546; czas: 44.844035387039185,
# Name: Schwefel plus  (min: 0): próba 0; wynik: 17775.831605989977; czas: 19.055187940597534
# Name: Schwefel plus  (min: 0): próba 1; wynik: 180153.56882088847; czas: 17.291992902755737
# Wynik Name: Schwefel plus  (min: 0): 17775.831605989977; czas: 36.69542074203491,
# Name: Schwefel  (min: 0): próba 0; wynik: 3946.3783058836466; czas: 13.987727880477905
# Name: Schwefel  (min: 0): próba 1; wynik: 2045.5750194598236; czas: 13.859159231185913
# Wynik Name: Schwefel  (min: 0): 2045.5750194598236; czas: 28.291627407073975,
# Name: Dixon & Price plus  (min: 0): próba 0; wynik: 377.26172035156685; czas: 33.9575936794281
# Name: Dixon & Price plus  (min: 0): próba 1; wynik: 312.4152397889899; czas: 32.846901178359985
# Wynik Name: Dixon & Price plus  (min: 0): 312.4152397889899; czas: 67.6350359916687,
# Name: Dixon & Price  (min: 0): próba 0; wynik: 439.76907722232374; czas: 27.223957061767578
# Name: Dixon & Price  (min: 0): próba 1; wynik: 239.78403382530087; czas: 34.15355896949768
# Wynik Name: Dixon & Price  (min: 0): 239.78403382530087; czas: 62.160634994506836,

# %%
benchData = namedtuple('benchData', 'func, domain, min, argmin')

benchList = {
    'Sphere':benchData(rast, (-5.12, 5.12), 0, "0,0,.."),
    'Griewank':benchData(griewank, (-500, 500), 0, "0,0,.."),
    'Rastrigin':benchData(rast, (-5.12, 5.12), 0, "0,0,.."),
    'Schwefel':benchData(rast, (-500, 500), 0, "1,1,.."),
    'Dixon & Price':benchData(rast, (-10, 10), 0, "0,0,.."),
}

evkwargs = {
        'mi':500,
        'Lambda':4000,
        'd':50,
        'number_of_iterations':400,
        'K':0.6,
}

pltkwargs = {
    'tries':2,
    'barplot':True,
    'file':False,
    'verbose' : True
}
for name in benchList:
    for plus in [True, False]:
        evkwargs = {
            **evkwargs,
            'population_evaluation': benchList[name].func,
            'domain': benchList[name].domain,
            'plus': plus
        }
        pltkwargs['title'] = f'Name: {name} {"plus " if plus else ""} (min: {benchList[name].min})'
        pltkwargs['filename'] = f'z1_{name}{"_plus " if plus else ""}'
        
        plot_scores(ES, **pltkwargs, **evkwargs)
